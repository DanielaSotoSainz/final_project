# %% [markdown]
# ## Get Coordinates from Google API

# %%
import requests
import os
import pandas as pd

# %%
# Load data
api_key = os.environ["google_maps_key"]
df = pd.read_csv("../../database/clean2/db_origin.csv")
df.head()
# Out:
#              token             state    municipality  altitude
# 0      HKSKLKNMKSK  Estado de Mexico    Huixquilucan      2726
# 1        MKSKTMLPN  Estado de Mexico        Timilpan      2741
# 2       STTKKNMKSK  Ciudad de Mexico        Coyoacan      2240
# 3      MKSKNSHLKTL  Estado de Mexico  Nezahualcoyotl      2220
# 4  ALFRSTTMKSKPRKN  Ciudad de Mexico  Alvaro Obregon      2373

# %%
# Make the requests, print results
coords = []
url = "https://maps.googleapis.com/maps/api/geocode/json?"
for state, city in df[["state", "municipality"]].values:
    query = f"{url}&address={city},{state}&key={api_key}"
    r = requests.get(query)
    data = r.json()
    location = data['results'][0]['geometry']['location']
    print(state, city)
    print(location)
    coords.append({'lat': location['lat'], 'lng': location['lng']})
coords
# Out:
# Estado de Mexico Huixquilucan
# {'lat': 19.3602606, 'lng': -99.3510312}
# Estado de Mexico Timilpan
# {'lat': 19.8745272, 'lng': -99.73580899999999}
# Ciudad de Mexico Coyoacan
# {'lat': 19.3486926, 'lng': -99.16291310000001}
# Estado de Mexico Nezahualcoyotl
# {'lat': 19.3994934, 'lng': -98.9896643}
# Ciudad de Mexico Alvaro Obregon
# {'lat': 19.3605334, 'lng': -99.2267067}
# Ciudad de Mexico Iztapalapa
# {'lat': 19.3467093, 'lng': -99.0798926}
# Estado de Mexico Metepec
# {'lat': 19.2528864, 'lng': -99.598551}
# Ciudad de Mexico Xochimilco
# {'lat': 19.2572314, 'lng': -99.1029664}
# Estado de Mexico Coacalco
# {'lat': 19.6290831, 'lng': -99.1043451}
# Estado de Mexico Chalco
# {'lat': 19.26244, 'lng': -98.8969427}
# Estado de Mexico Toluca
# {'lat': 19.2826098, 'lng': -99.6556653}
# Estado de Mexico Tlacotepec
# {'lat': 18.9649315, 'lng': -99.93294949999999}
# Estado de Mexico San Antonio La Isla
# {'lat': 19.1610361, 'lng': -99.5704448}
# Estado de Mexico Chimalhuacan
# {'lat': 19.4314047, 'lng': -98.95820479999999}
# Ciudad de Mexico Tlahuac
# {'lat': 19.2990233, 'lng': -99.0436467}
# Estado de Mexico Los Olivos
# {'lat': 19.3952321, 'lng': -98.9759496}
# Ciudad de Mexico Milpa Alta
# {'lat': 19.1942041, 'lng': -99.0267076}
# Chihuahua Juarez
# {'lat': 31.6903638, 'lng': -106.4245478}
# Guerrero Cutzamala de Pinzon
# {'lat': 18.4671282, 'lng': -100.5796111}
# Hidalgo Pachuca de Soto
# {'lat': 20.1010608, 'lng': -98.7591311}
# Ciudad de Mexico Tlalpan
# {'lat': 19.2777349, 'lng': -99.1644701}
# Estado de Mexico San Jose del Rincon
# {'lat': 19.6612661, 'lng': -100.1570626}
# Guerrero Chilpancingo de los Bravo
# {'lat': 17.5515346, 'lng': -99.5006322}
# Puebla Puebla
# {'lat': 19.0414398, 'lng': -98.2062727}
# Ciudad de Mexico Gustavo A Madero
# {'lat': 19.4873329, 'lng': -99.1236134}
# Guerrero Chilapa
# {'lat': 17.597969, 'lng': -99.1758462}
# Aguascalientes Aguascalientes
# {'lat': 21.8852562, 'lng': -102.2915677}
# Guanajuato Valle de Santiago
# {'lat': 20.3905935, 'lng': -101.1938304}
# Morelos Miacatlan
# {'lat': 18.7717876, 'lng': -99.3534348}
# Veracruz Papantla
# {'lat': 20.4566709, 'lng': -97.3156131}
# Guerrero Ayutla de los Libres
# {'lat': 16.9658305, 'lng': -99.0930528}
# Estado de Mexico Atizapan de Zaragoza
# {'lat': 19.5562275, 'lng': -99.2674713}
# Veracruz Santiago Tuxtla
# {'lat': 18.4634757, 'lng': -95.3024094}
# Ciudad de Mexico Iztacalco
# {'lat': 19.3948036, 'lng': -99.09768079999999}
# Morelos Temixco
# {'lat': 18.8593026, 'lng': -99.2393666}
# Coahuila Torreon
# {'lat': 25.5428443, 'lng': -103.4067861}
# Veracruz Playa Vicente
# {'lat': 17.8304345, 'lng': -95.81316350000002}
# Guerrero Ometepec
# {'lat': 16.6908954, 'lng': -98.4101984}
# Estado de Mexico Ecatepec de Morelos
# {'lat': 19.6057728, 'lng': -99.03651119999999}
# Estado de Mexico Ixtapaluca
# {'lat': 19.3090538, 'lng': -98.9079782}
# Ciudad de Mexico Miguel Hidalgo
# {'lat': 19.4306575, 'lng': -99.20839529999999}
# Veracruz Jalapa
# {'lat': 19.5437751, 'lng': -96.91018059999999}
# Guerrero Zihuatanejo
# {'lat': 17.6416693, 'lng': -101.5516955}
# Estado de Mexico Melchor Ocampo
# {'lat': 19.7031072, 'lng': -99.14349639999999}
# Guerrero Acatepec
# {'lat': 17.3241189, 'lng': -98.90962309999999}
# Morelos Emiliano Zapata
# {'lat': 18.8478608, 'lng': -99.1843676}
# Yucatan Merida
# {'lat': 20.9673702, 'lng': -89.5925857}
# Jalisco Arandas
# {'lat': 20.705519, 'lng': -102.346916}
# Guerrero Copanatoyac
# {'lat': 17.4644481, 'lng': -98.7125904}
# Estado de Mexico Texcoco
# {'lat': 19.5060382, 'lng': -98.8831503}
# Estado de Mexico Tejupilco
# {'lat': 18.9062177, 'lng': -100.1507188}
# Yucatan Hunucma
# {'lat': 21.016318, 'lng': -89.8772303}
# Hidalgo Francisco I Madero
# {'lat': 20.2450994, 'lng': -99.0905389}
# Estado de Mexico Naucalpan
# {'lat': 19.4737133, 'lng': -99.2336657}
# Baja California Ensenada
# {'lat': 31.8667427, 'lng': -116.5963713}
# Estado de Mexico Los Reyes La paz
# {'lat': 19.3611697, 'lng': -98.95603650000001}
# Tamaulipas Reynosa
# {'lat': 26.0508406, 'lng': -98.29789509999999}
# Guerrero Acapulco de Juarez
# {'lat': 16.8531086, 'lng': -99.8236533}
# Tamaulipas San Fernando
# {'lat': 24.8419162, 'lng': -98.1502433}
# Hidalgo Tizayuca
# {'lat': 19.8405004, 'lng': -98.9801651}
# Ciudad de Mexico Magdalena Contreras
# {'lat': 19.3149641, 'lng': -99.24258859999999}
# Ciudad de Mexico Venustiano Carranza
# {'lat': 19.4306069, 'lng': -99.0949899}
# Estado de Mexico Nicolas Romero
# {'lat': 19.6162033, 'lng': -99.30011809999999}
# Jalisco Guadalajara
# {'lat': 20.6596988, 'lng': -103.3496092}
# Puebla Nealtican
# {'lat': 19.0482747, 'lng': -98.42693840000001}
# Sonora Hermosillo
# {'lat': 29.0729673, 'lng': -110.9559192}
# Guerrero Tecpan de Galeana
# {'lat': 17.2237303, 'lng': -100.6281014}
# Hidalgo Cardonal
# {'lat': 20.6124, 'lng': -99.1150509}
# Morelos Cuernavaca
# {'lat': 18.9242095, 'lng': -99.22156590000002}
# Sonora Guaymas
# {'lat': 27.9178651, 'lng': -110.9089378}
# Michoacan Michoacan
# {'lat': 19.5665192, 'lng': -101.7068294}
# Estado de Mexico Almoloya de Juarez
# {'lat': 19.3690064, 'lng': -99.7605116}
# Estado de Mexico Otumba
# {'lat': 19.6988525, 'lng': -98.75751}
# Ciudad de Mexico Cuajimalpa
# {'lat': 19.3557507, 'lng': -99.2993504}
# Estado de Mexico Tlalnepantla
# {'lat': 19.5345279, 'lng': -99.19073639999999}
# Queretaro Queretaro
# {'lat': 20.5887932, 'lng': -100.3898881}
# Sonora Cananea
# {'lat': 30.9897648, 'lng': -110.289179}
# Sonora Cumpas
# {'lat': 29.9946928, 'lng': -109.7803082}
# Jalisco Ayutla de los Libres
# {'lat': 20.1280233, 'lng': -104.3439311}
# Estado de Mexico Temamatla
# {'lat': 19.2017642, 'lng': -98.8721186}
# Guerrero Azoyu
# {'lat': 16.7325349, 'lng': -98.6034009}
# Guerrero Mochitlan
# {'lat': 17.4709149, 'lng': -99.3712917}
# Sonora Nogales
# {'lat': 31.3011855, 'lng': -110.9381047}
# Michoacan Maravatio
# {'lat': 19.8954098, 'lng': -100.4477181}
# Ciudad de Mexico Azcapotzalco
# {'lat': 19.4846606, 'lng': -99.1886749}
# Puebla Pantepec
# {'lat': 20.5193016, 'lng': -97.9380732}
# Ciudad de Mexico Cuauhtemoc
# {'lat': 19.4356338, 'lng': -99.1495107}
# Guerrero Tlalchapa
# {'lat': 18.4085169, 'lng': -100.4773801}
# Sonora Los Alamos
# {'lat': 27.0254869, 'lng': -108.941309}
# Estado de Mexico Cuautitlan Izcalli
# {'lat': 19.6528089, 'lng': -99.22313869999999}
# Chiapas Villaflores
# {'lat': 16.2329693, 'lng': -93.2734517}
# Estado de Mexico Jiquipilco
# {'lat': 19.5573493, 'lng': -99.60675309999999}
# Tamaulipas Altamira
# {'lat': 22.4077462, 'lng': -97.92115550000001}
# Guerrero Copala
# {'lat': 16.6030715, 'lng': -98.9714623}
# Estado de Mexico Ozumba de Alzate
# {'lat': 19.0376395, 'lng': -98.79602349999999}
# Guanajuato Salamanca
# {'lat': 20.5739314, 'lng': -101.1957172}
# Puebla Huauchinango
# {'lat': 20.1757001, 'lng': -98.0628862}
# Oaxaca Santa Cruz Zenzontepec
# {'lat': 16.5334303, 'lng': -97.4953304}
# Estado de Mexico Lomas de Coacalco
# {'lat': 19.6198998, 'lng': -99.0954726}
# Queretaro Pedro Escobedo
# {'lat': 20.5010443, 'lng': -100.1395169}
# Campeche Escarcega
# {'lat': 18.6101834, 'lng': -90.7390245}
# Estado de Mexico Cuajimalpa
# {'lat': 19.3557507, 'lng': -99.2993504}
# Tabasco Tabasco
# {'lat': 17.8409173, 'lng': -92.6189273}
# Estado de Mexico Estado de Mexico
# {'lat': 19.4231994, 'lng': -99.04328869999999}
# Michoacan Tarimbaro
# {'lat': 19.7911756, 'lng': -101.1758932}
# Oaxaca Santa Cruz Xoxocotlan
# {'lat': 17.0193584, 'lng': -96.74942159999999}
# Guanajuato Celaya
# {'lat': 20.5279612, 'lng': -100.8112885}
# Morelos Jojutla
# {'lat': 18.6144195, 'lng': -99.1781178}
# Nuevo Leon Monterrey
# {'lat': 25.6866142, 'lng': -100.3161126}
# Oaxaca Villa de Tamazulapam
# {'lat': 17.6724247, 'lng': -97.57204809999999}
# Guerrero Copalillo
# {'lat': 18.0344322, 'lng': -99.0406186}
# Queretaro Corregidora
# {'lat': 20.5334645, 'lng': -100.4462861}
# Veracruz Xalapa
# {'lat': 19.5437751, 'lng': -96.91018059999999}
# Nayarit Santiago Ixcuintla
# {'lat': 21.8131863, 'lng': -105.204327}
# Puebla Yehualtepec
# {'lat': 18.795868, 'lng': -97.6629495}
# Estado de Mexico Tecamac
# {'lat': 19.7122732, 'lng': -98.96830729999999}
# Estado de Mexico Tenango del Vale
# {'lat': 19.1053422, 'lng': -99.58821309999999}
# Guerrero Huitziltepec
# {'lat': 17.757147, 'lng': -99.479771}
# Veracruz Boca del Rio
# {'lat': 19.106273, 'lng': -96.10632040000002}
# Michoacan Jacona
# {'lat': 19.9534201, 'lng': -102.3068608}
# Estado de Mexico Lerma
# {'lat': 19.2913424, 'lng': -99.5244687}
# Hidalgo Tulancingo de bravo
# {'lat': 20.0904802, 'lng': -98.3690922}
# Hidalgo  San Felipe Orizatlan
# {'lat': 21.1690704, 'lng': -98.61331880000002}
# Estado de Mexico Calimaya
# {'lat': 19.1617587, 'lng': -99.6178249}
# Yucatan Kanasin
# {'lat': 20.9441486, 'lng': -89.56391190000001}
# Tabasco Villa Hermosa
# {'lat': 17.989456, 'lng': -92.9475061}
# Chihuahua Chihuahua
# {'lat': 28.6329957, 'lng': -106.0691004}
# Hidalgo Santiago de Anaya
# {'lat': 20.3800556, 'lng': -98.9631789}
# Tlaxcala Tlaxcala
# {'lat': 19.318154, 'lng': -98.2374954}
# Guerrero Iguala
# {'lat': 18.3448477, 'lng': -99.5397344}
# Estado de Mexico Hueypoxtla
# {'lat': 19.9109342, 'lng': -99.07590739999999}
# Estado de Mexico San Felipe del Progreso
# {'lat': 19.7129957, 'lng': -99.9515474}
# Michoacan Periban
# {'lat': 19.519222, 'lng': -102.4138738}
# Jalisco Zapopan
# {'lat': 20.6719563, 'lng': -103.416501}
# Queretaro El Marques
# {'lat': 20.6113606, 'lng': -100.3288581}
# Estado de Mexico Tultitlan
# {'lat': 19.6392125, 'lng': -99.1668646}
# Guanajuato Irapuato
# {'lat': 20.6786652, 'lng': -101.3544964}
# Michoacan Tancitaro
# {'lat': 19.3368654, 'lng': -102.3624818}
# Veracruz Amatlan Tuxpan
# {'lat': 21.3312719, 'lng': -97.754333}
# Hidalgo Tlahuiltepa
# {'lat': 20.9233609, 'lng': -98.9500652}
# Oaxaca Matias Romero
# {'lat': 16.8681196, 'lng': -95.0442567}
# Guanajuato Uriangato
# {'lat': 20.1462015, 'lng': -101.178725}
# Tamaulipas Tampico
# {'lat': 22.2331041, 'lng': -97.861099}
# Yucatan Yobain
# {'lat': 21.2335619, 'lng': -89.1166404}
# Texas Plainview
# {'lat': 34.1847936, 'lng': -101.7068417}
# Tlaxcala Panotla
# {'lat': 19.3124375, 'lng': -98.2732659}
# Veracruz Oteapan
# {'lat': 17.9978524, 'lng': -94.6708709}
# Guerrero Martin de Cuilapan
# {'lat': 17.741043, 'lng': -99.32708149999999}
# Guerrero San Marcos
# {'lat': 16.7949714, 'lng': -99.3883874}
# Oaxaca Huajuapan de Leon
# {'lat': 17.8112504, 'lng': -97.78034819999999}
# Hidalgo Zapotlan de Juarez
# {'lat': 19.9763386, 'lng': -98.86430589999999}
# Oaxaca Santa Maria Colotepec
# {'lat': 15.8969852, 'lng': -96.93780509999999}
# Morelos Zacatepec
# {'lat': 18.6590633, 'lng': -99.1954432}
# Morelos Yautepec
# {'lat': 18.8891562, 'lng': -99.0626377}
# Veracruz Tamarindo Carrillo Puerto
# {'lat': 18.800258, 'lng': -96.571704}
# Estado de Mexico Jocotitlan
# {'lat': 19.7075577, 'lng': -99.78839669999999}
# Oaxaca Oaxaca
# {'lat': 17.0731842, 'lng': -96.7265889}
# Morelos Hueyapan
# {'lat': 18.8860004, 'lng': -98.6908754}
# Guerrero Eduardo Neri
# {'lat': 17.6520624, 'lng': -99.5249616}
# Hidalgo Atotonilco el Grande
# {'lat': 20.2865414, 'lng': -98.66890339999999}
# Oaxaca San Juan Bautista Tuxtepec
# {'lat': 18.0809028, 'lng': -96.1420947}
# Tamaulipas Matamoros
# {'lat': 25.8690294, 'lng': -97.50273759999999}
# Oaxaca Santiago Ayuquililla
# {'lat': 17.9309132, 'lng': -97.9579242}
# Estado de Mexico Ixtlahuaca
# {'lat': 19.5699879, 'lng': -99.7650659}
# Estado de Mexico Tultepec
# {'lat': 19.6860054, 'lng': -99.1260866}
# Morelos Jiutepec
# {'lat': 18.8954874, 'lng': -99.1732936}
# Michoacan Contepec
# {'lat': 19.9521591, 'lng': -100.1619222}
# Quintana Roo Playa del Carmen
# {'lat': 20.6295586, 'lng': -87.0738851}
# Chiapas Tuxtla Gutierrez
# {'lat': 16.7516009, 'lng': -93.1029939}
# Estado de Mexico Huehuetoca
# {'lat': 19.8277305, 'lng': -99.2037508}
# Quintana Roo Benito Juarez
# {'lat': 21.1139789, 'lng': -86.9423801}
# Veracruz Espinal
# {'lat': 20.2588917, 'lng': -97.4011206}
# Estado de Mexico Temacac
# {'lat': 19.7122732, 'lng': -98.96830729999999}
# Hidalgo Cuautepec de Hinojosa
# {'lat': 20.0368036, 'lng': -98.3170569}
# Ciudad de Mexico Benito Juarez
# {'lat': 19.3794059, 'lng': -99.15914459999999}
# Puebla San SebastianTlacotepec
# {'lat': 18.4041547, 'lng': -96.8494583}
# Estado de Mexico Atlacomulco
# {'lat': 19.7975581, 'lng': -99.8766825}
# Oaxaca Juchitan
# {'lat': 16.4406909, 'lng': -95.0221197}
# Hidalgo Arenal El
# {'lat': 40.2738765, 'lng': -5.0858988}
# Hidalgo Atitalaquia
# {'lat': 20.0509779, 'lng': -99.2203687}
# Estado de Mexico Zumpango
# {'lat': 19.8039297, 'lng': -99.0930528}
# San Luis Potosi Villa de Reyes
# {'lat': 21.8058423, 'lng': -100.9324541}
# Estado de Mexico Teotihuacan
# {'lat': 19.6860799, 'lng': -98.87163609999999}
# Michoacan Morelia
# {'lat': 19.7059504, 'lng': -101.1949825}
# Puebla Tehuitzingo
# {'lat': 18.3297054, 'lng': -98.27585309999999}
# Michoacan Zamora
# {'lat': 19.9901766, 'lng': -102.2834075}
# Morelos Xoxocotla
# {'lat': 18.6850824, 'lng': -99.2460619}
# Veracruz Tierra Blanca
# {'lat': 18.4458276, 'lng': -96.3598367}
# Estado de Mexico Juchitepec
# {'lat': 19.091141, 'lng': -98.881554}
# Morelos Tetela del volcan
# {'lat': 18.8937717, 'lng': -98.7205877}
# Estado de Mexico San Mateo Atenco
# {'lat': 19.2630031, 'lng': -99.5324296}
# Puebla Cholula
# {'lat': 19.0765772, 'lng': -98.30211919999999}
# Estado de Mexico Tenancingo
# {'lat': 18.9613407, 'lng': -99.59107379999999}
# Quintana Roo Chetumal
# {'lat': 18.5001889, 'lng': -88.296146}
# Hidalgo Huasca de Ocampo
# {'lat': 20.2040455, 'lng': -98.5754259}
# Puebla Pahuatlan
# {'lat': 20.2769343, 'lng': -98.15016089999999}
# Veracruz Ixtaczoquitlan
# {'lat': 18.8608694, 'lng': -97.063289}
# Sinaloa Culiacan
# {'lat': 24.8090649, 'lng': -107.3940117}
# Sinaloa Los Mochis
# {'lat': 25.7904657, 'lng': -108.985882}
# Estado de Mexico Villa del Carbon
# {'lat': 19.7287602, 'lng': -99.4617111}
# Yucatan Los Heroes
# {'lat': 20.9891255, 'lng': -89.538319}
# Estado de Mexico Jilotepec
# {'lat': 19.9516359, 'lng': -99.536755}
# Puebla Calpaneria Atezequilla
# {'lat': 19.6551519, 'lng': -97.9931142}
# Estado de Mexico Termascalcingo
# {'lat': 19.9198874, 'lng': -100.0052044}
# Estado de Mexico San Salvador Atenco
# {'lat': 19.5610315, 'lng': -98.9169257}
# Aguascalientes Valle Ceylan
# {'lat': 19.5386018, 'lng': -99.1809533}
# Michoacan Cristo Rey
# {'lat': 20.0550773, 'lng': -102.7318272}
# Guerrero Chilpancingo de los Bravos
# {'lat': 17.5515346, 'lng': -99.5006322}
# Jalisco Puerto Vallarta
# {'lat': 20.653407, 'lng': -105.2253316}
# Baja California Vicente Guerrero
# {'lat': 30.7286487, 'lng': -115.9894616}
# Ciudad de Mexico Nezahualcoyotl
# {'lat': 19.3994934, 'lng': -98.9896643}
# Estado de Mexico Tlalnepantla de Baz
# {'lat': 19.5345279, 'lng': -99.19073639999999}
# Tabasco La Huerta
# {'lat': 18.0737638, 'lng': -92.875481}
# Chihuahua Ampliacion Insurgentes
# {'lat': 28.6979423, 'lng': -106.1261175}
# Estado de Mexico Valle Nicolas Romero
# {'lat': 19.6087519, 'lng': -99.3115412}
# Puebla Francisco Z Mena
# {'lat': 20.7329044, 'lng': -97.8500845}
# Estado de Mexico  Naucalpan de Juarez
# {'lat': 19.4737133, 'lng': -99.2336657}
# Estado de Mexico Nicolar Romero
# {'lat': 19.6240978, 'lng': -99.30717469999999}
# Hidalgo Huichapan
# {'lat': 20.3786677, 'lng': -99.6508401}
# Estado de Mexico Tequistlan
# {'lat': 19.5966042, 'lng': -98.9402176}
# Estado de Mexico Tlanepantla
# {'lat': 19.5345279, 'lng': -99.19073639999999}
# Ciudad de Mexico Xoxhimilco
# {'lat': 19.2572314, 'lng': -99.1029664}
# Coahuila Saltillo
# {'lat': 25.4383234, 'lng': -100.973678}
# Zacatecas La Honda
# {'lat': 24.0205555, 'lng': -103.4072222}
# Guerrero Chilpancingo
# {'lat': 17.5515346, 'lng': -99.5006322}
# Estado de Mexico  Santa Catarina Ayotzingo
# {'lat': 19.2078994, 'lng': -98.93108389999999}
# Oaxaca Brizas de Zicatela
# {'lat': 15.8336944, 'lng': -97.0424994}
# Guerrero Almoloya
# {'lat': 18.3680555, 'lng': -100.1761111}
# Puebla Puebla de Zaragoza
# {'lat': 19.0414398, 'lng': -98.2062727}
# Estado de Mexico Allende
# {'lat': 19.4755229, 'lng': -99.7149999}
# Estado de Mexico San Lorenzo
# {'lat': 19.4045962, 'lng': -98.972843}
# Estado de Mexico Atizapan
# {'lat': 19.5562275, 'lng': -99.2674713}
# Estado de Mexico Ecatepec
# {'lat': 19.6057728, 'lng': -99.03651119999999}
# Estado de Mexico Temoaya
# {'lat': 19.4653884, 'lng': -99.59404169999999}
# Baja California Sur Loma encantada
# {'lat': 23.0122675, 'lng': -109.7352487}
# Ciudad de Mexico Avaro Obregon
# {'lat': 19.3605334, 'lng': -99.2267067}
# San Luis Potosi Prados San Vicente
# {'lat': 22.1325826, 'lng': -100.9136055}
# Puebla Tehuacan
# {'lat': 18.4665063, 'lng': -97.40038009999999}
# Estado de Mexico Acolman
# {'lat': 19.6420614, 'lng': -98.9107373}
# Quintana Roo Solidaridad
# {'lat': 20.5501224, 'lng': -87.42075179999999}
# San Luis Potosi San Luis Potosi
# {'lat': 22.1564699, 'lng': -100.9855409}
# Tabasco Paraiso
# {'lat': 18.4006144, 'lng': -93.2127162}
# Veracruz Tontoyuca
# {'lat': 21.3510619, 'lng': -98.2267665}
# Oaxaca Magdalena Teitipac
# {'lat': 16.9046705, 'lng': -96.5596566}
# Hidalgo Tetepango
# {'lat': 20.0988308, 'lng': -99.15115019999999}
# Durango Durango
# {'lat': 24.0277202, 'lng': -104.6531759}
# Michoacan de Ocampo Contepec
# {'lat': 19.9521591, 'lng': -100.1619222}
# Oaxaca Loma Bonita
# {'lat': 18.109679, 'lng': -95.8803616}
# Estado de Mexico  Atlacomulco
# {'lat': 19.7975581, 'lng': -99.8766825}
# Sonora Hermosillo
# {'lat': 29.0729673, 'lng': -110.9559192}
# Estado de Mexico Otzolotepec
# {'lat': 19.4117213, 'lng': -99.5592077}
# Colima Colima
# {'lat': 19.2452342, 'lng': -103.7240868}
# Tlaxcala Emiliano Zapata
# {'lat': 19.5576533, 'lng': -97.9165939}
# Hidalgo Atotonilco de Tula
# {'lat': 20.0096889, 'lng': -99.2203687}
# Ciudad de Mexico  Azcapotzalco
# {'lat': 19.4846606, 'lng': -99.1886749}
# Sonora Magdalena
# {'lat': 30.6248514, 'lng': -110.9714055}
# Guerrero Tixtla de Guerrero
# {'lat': 17.567656, 'lng': -99.39959239999999}
# Estado de Mexico Coacalco de Berriozabal
# {'lat': 19.6326046, 'lng': -99.1090105}
# Jalisco Ixtlahuacan de los Membrillos
# {'lat': 20.3475108, 'lng': -103.1942224}
# Estado de Mexico  Cuautitlan
# {'lat': 19.6726588, 'lng': -99.1648692}
# Hidalgo Acatlan
# {'lat': 20.1453958, 'lng': -98.4410429}
# Oaxaca San Antonino Monte Verde
# {'lat': 17.5330507, 'lng': -97.7214489}
# Hidalgo Tepeji del Rio de Ocampo
# {'lat': 19.9114508, 'lng': -99.3506604}
# Estado de Mexico Xonacatlan
# {'lat': 19.4042181, 'lng': -99.5302705}
# Puebla Atempan
# {'lat': 19.8379586, 'lng': -97.4564439}
# Hidalgo  Tecozautla
# {'lat': 20.5326359, 'lng': -99.6323321}
# Estado de Mexico Tianguistenco
# {'lat': 19.1804002, 'lng': -99.467615}
# Estado de Mexico Lluvianos
# {'lat': 18.9200983, 'lng': -100.2978762}
# Baja California  Tijuana
# {'lat': 32.5149469, 'lng': -117.0382471}
# Guanajuato Silao de la Victoria
# {'lat': 20.952141, 'lng': -101.4282369}
# Michoacan Chilchota
# {'lat': 19.8464674, 'lng': -102.1176991}
# Tabasco Centro
# {'lat': 17.9915076, 'lng': -92.9344412}
# Oaxaca Santiago Pinotepa Nacional
# {'lat': 16.3411824, 'lng': -98.053687}
# Belize  Orange walk
# {'lat': 18.0842472, 'lng': -88.5710266}
# Estado de Mexico Morelos
# {'lat': 19.7899891, 'lng': -99.6684882}
# Estado de Mexico Ixtapan de la sal
# {'lat': 18.8390501, 'lng': -99.6760096}
# Estado de Mexico Temascalcingo
# {'lat': 19.9198874, 'lng': -100.0052044}
# Guerrero Zirandaro
# {'lat': 18.4753174, 'lng': -100.9769179}
# Estado de Mexico Ciudad Nezahualcoyot
# {'lat': 19.3994934, 'lng': -98.9896643}
# Baja California Sur Los cabos
# {'lat': 22.8905327, 'lng': -109.9167371}
# Hidalgo Tenango de Doria
# {'lat': 20.3367247, 'lng': -98.2240321}
# Morelos Ocotitlan
# {'lat': 18.9892416, 'lng': -99.0594645}
# Hidalgo Huejutla
# {'lat': 21.1367171, 'lng': -98.41221619999999}
# Veracruz Zongolica
# {'lat': 18.6655167, 'lng': -96.99800839999999}
# Estado de Mexico  Ecatepec
# {'lat': 19.6057728, 'lng': -99.03651119999999}
#  Veracruz Uxpanapa
# {'lat': 17.2772992, 'lng': -94.4506177}
# Estado de Mexico  Llano de los Vaez
# {'lat': 19.6126719, 'lng': -99.012202}
# Ciudad de Mexico  Milpa Alta
# {'lat': 19.1942041, 'lng': -99.0267076}
# Guerrero Cuajinicuilapa
# {'lat': 16.4711295, 'lng': -98.4151885}
# Guerrero Pueblo Huerta Vieja
# {'lat': 17.8886548, 'lng': -100.1991306}
# Estado de Mexico San Jose del Rincon
# {'lat': 19.6612661, 'lng': -100.1570626}
# Oaxaca Culipam de Guerrero
# {'lat': 16.9914845, 'lng': -96.7788461}
# Guerrero Los Cascalotes
# {'lat': 18.3640239, 'lng': -99.5523977}
# Hidalgo Huehuetla
# {'lat': 20.460486, 'lng': -98.0751645}
# Estado de Mexico Santiago Tilapa
# {'lat': 19.1864227, 'lng': -99.4192351}
# Hidalgo Mineral de la Reforma
# {'lat': 20.0708947, 'lng': -98.6960424}
# Campeche Champoton
# {'lat': 19.3471645, 'lng': -90.7200237}
# Campeche Holpechen
# {'lat': 19.7472419, 'lng': -89.8424644}
# Hidalgo Zacualtipan
# {'lat': 20.6484047, 'lng': -98.6535693}
# Estado de Mexico Cocotitlan
# {'lat': 19.2314995, 'lng': -98.8666032}
# Guerrero Tepecoacuilco de trujano
# {'lat': 18.2843822, 'lng': -99.46448930000001}
# Veracruz Martinez de la Torre
# {'lat': 20.0615132, 'lng': -97.05452559999999}
# Ciuidad de Mexico Barrio de Santa Martha
# {'lat': 19.3615578, 'lng': -99.0087486}
# Campeche Carmen
# {'lat': 18.6504879, 'lng': -91.80745859999999}
# Hidalgo  Tizayuca
# {'lat': 19.8405004, 'lng': -98.9801651}
# Guerrero  Arcelia
# {'lat': 18.3151454, 'lng': -100.2851493}
# Hidalgo Ixmiquilpan
# {'lat': 20.4831412, 'lng': -99.21711739999999}
# Guerrero Chilapa de Alavrez
# {'lat': 17.597969, 'lng': -99.1758462}
# Guerrero Acapulco
# {'lat': 16.8531086, 'lng': -99.8236533}
# Michoacan Uruapan
# {'lat': 19.4064492, 'lng': -102.0430476}
# Estado de Mexico  Las Aguilas
# {'lat': 19.3795136, 'lng': -99.0032236}
# Hidalgo Acaxochitlan
# {'lat': 20.1544793, 'lng': -98.20216099999999}
# Puebla Tepeaca
# {'lat': 18.9659554, 'lng': -97.8993756}
# Oaxaca Santa Maria Tonameca
# {'lat': 15.7467124, 'lng': -96.5462836}
# Oaxaca Ixtlan de Juarez
# {'lat': 17.3321811, 'lng': -96.4873643}
# Puebla San Miguel Tlalancaleca
# {'lat': 19.3256113, 'lng': -98.4964685}
# Oaxaca Cerro de la Esperanza
# {'lat': 16.211181, 'lng': -97.9792049}
# Ciuidad de Mexico Ixtapalapa
# {'lat': 19.3467093, 'lng': -99.0798926}
# Quintana Roo Jose Maria Morelos
# {'lat': 19.7485675, 'lng': -88.706081}
# Sonora Navojoa
# {'lat': 27.0727573, 'lng': -109.4437493}
# Ciudad de Mexico Alvaro Obregon
# {'lat': 19.3605334, 'lng': -99.2267067}
# Ciuidad de Mexico San Miguel Teotongo
# {'lat': 19.3434287, 'lng': -98.9880319}
# Hidalgo Pachuca
# {'lat': 20.1010608, 'lng': -98.7591311}
# Estadio de Mexico  Atenco
# {'lat': 19.5610315, 'lng': -98.9169257}
# Hidalgo  Tezontepec
# {'lat': 19.8820941, 'lng': -98.8218954}
# Puebla Caxhoacan
# {'lat': 20.0633589, 'lng': -97.6065055}
# Veracruz Huatusco
# {'lat': 19.1482351, 'lng': -96.9665476}
# Estado de Mexico San Juan Teotihuacan
# {'lat': 19.6860799, 'lng': -98.87163609999999}
# Tlaxcala Venustiano Carranza
# {'lat': 19.4044079, 'lng': -98.0656145}
# Estado de Mexico Zumpahuacan
# {'lat': 18.8345654, 'lng': -99.5814814}
# Tlaxcala Nanacamilpa
# {'lat': 19.4949991, 'lng': -98.5363982}
# Veracruz Minatitlan
# {'lat': 17.9939225, 'lng': -94.5466067}
# Oaxaca San Bartolo Coyotepec
# {'lat': 16.9541863, 'lng': -96.7079287}
# Estado de Mexico  Atizapan de Zaragoza
# {'lat': 19.5562275, 'lng': -99.2674713}
# Veracruz Hueyapan de Ocampo
# {'lat': 18.1504792, 'lng': -95.1453617}
# Guerrero  Acapulco de Juarez
# {'lat': 16.8531086, 'lng': -99.8236533}
# San Luis Potosi Ciudad Fernandez
# {'lat': 21.9368487, 'lng': -100.0303723}
# Oaxaca San Antonio Tepetlapa
# {'lat': 16.5418499, 'lng': -98.0651101}
# Estado de Mexico Villa Victoria
# {'lat': 19.4376729, 'lng': -99.9954161}
# Veracruz Panuco
# {'lat': 22.0535642, 'lng': -98.1820596}
# Guerrero Cuetzala del Progreso
# {'lat': 18.134678, 'lng': -99.8324514}
# Estado de Mexico Estancia Grande
# {'lat': 19.4968732, 'lng': -99.72326729999999}
# Campeche Hecelchakan
# {'lat': 20.1819021, 'lng': -90.13545859999999}
# Hidalgo  Mixquiahuala
# {'lat': 20.2304048, 'lng': -99.21065510000001}
# Hidalgo  Huautla de Jimenez
# {'lat': 18.1310861, 'lng': -96.84314020000001}
# Veracruz  Catemaco
# {'lat': 18.4212621, 'lng': -95.1129658}
# Estado de Mexico Amanalco
# {'lat': 19.2540675, 'lng': -100.0195984}
# Oaxaca Chalcatongo
# {'lat': 17.0308889, 'lng': -97.5708659}
# Hidalgo Atotonilco el Grande
# {'lat': 20.2865414, 'lng': -98.66890339999999}
# [{'lat': 19.3602606, 'lng': -99.3510312},
#  {'lat': 19.8745272, 'lng': -99.73580899999999},
#  {'lat': 19.3486926, 'lng': -99.16291310000001},
#  {'lat': 19.3994934, 'lng': -98.9896643},
#  {'lat': 19.3605334, 'lng': -99.2267067},
#  {'lat': 19.3467093, 'lng': -99.0798926},
#  {'lat': 19.2528864, 'lng': -99.598551},
#  {'lat': 19.2572314, 'lng': -99.1029664},
#  {'lat': 19.6290831, 'lng': -99.1043451},
#  {'lat': 19.26244, 'lng': -98.8969427},
#  {'lat': 19.2826098, 'lng': -99.6556653},
#  {'lat': 18.9649315, 'lng': -99.93294949999999},
#  {'lat': 19.1610361, 'lng': -99.5704448},
#  {'lat': 19.4314047, 'lng': -98.95820479999999},
#  {'lat': 19.2990233, 'lng': -99.0436467},
#  {'lat': 19.3952321, 'lng': -98.9759496},
#  {'lat': 19.1942041, 'lng': -99.0267076},
#  {'lat': 31.6903638, 'lng': -106.4245478},
#  {'lat': 18.4671282, 'lng': -100.5796111},
#  {'lat': 20.1010608, 'lng': -98.7591311},
#  {'lat': 19.2777349, 'lng': -99.1644701},
#  {'lat': 19.6612661, 'lng': -100.1570626},
#  {'lat': 17.5515346, 'lng': -99.5006322},
#  {'lat': 19.0414398, 'lng': -98.2062727},
#  {'lat': 19.4873329, 'lng': -99.1236134},
#  {'lat': 17.597969, 'lng': -99.1758462},
#  {'lat': 21.8852562, 'lng': -102.2915677},
#  {'lat': 20.3905935, 'lng': -101.1938304},
#  {'lat': 18.7717876, 'lng': -99.3534348},
#  {'lat': 20.4566709, 'lng': -97.3156131},
#  {'lat': 16.9658305, 'lng': -99.0930528},
#  {'lat': 19.5562275, 'lng': -99.2674713},
#  {'lat': 18.4634757, 'lng': -95.3024094},
#  {'lat': 19.3948036, 'lng': -99.09768079999999},
#  {'lat': 18.8593026, 'lng': -99.2393666},
#  {'lat': 25.5428443, 'lng': -103.4067861},
#  {'lat': 17.8304345, 'lng': -95.81316350000002},
#  {'lat': 16.6908954, 'lng': -98.4101984},
#  {'lat': 19.6057728, 'lng': -99.03651119999999},
#  {'lat': 19.3090538, 'lng': -98.9079782},
#  {'lat': 19.4306575, 'lng': -99.20839529999999},
#  {'lat': 19.5437751, 'lng': -96.91018059999999},
#  {'lat': 17.6416693, 'lng': -101.5516955},
#  {'lat': 19.7031072, 'lng': -99.14349639999999},
#  {'lat': 17.3241189, 'lng': -98.90962309999999},
#  {'lat': 18.8478608, 'lng': -99.1843676},
#  {'lat': 20.9673702, 'lng': -89.5925857},
#  {'lat': 20.705519, 'lng': -102.346916},
#  {'lat': 17.4644481, 'lng': -98.7125904},
#  {'lat': 19.5060382, 'lng': -98.8831503},
#  {'lat': 18.9062177, 'lng': -100.1507188},
#  {'lat': 21.016318, 'lng': -89.8772303},
#  {'lat': 20.2450994, 'lng': -99.0905389},
#  {'lat': 19.4737133, 'lng': -99.2336657},
#  {'lat': 31.8667427, 'lng': -116.5963713},
#  {'lat': 19.3611697, 'lng': -98.95603650000001},
#  {'lat': 26.0508406, 'lng': -98.29789509999999},
#  {'lat': 16.8531086, 'lng': -99.8236533},
#  {'lat': 24.8419162, 'lng': -98.1502433},
#  {'lat': 19.8405004, 'lng': -98.9801651},
#  {'lat': 19.3149641, 'lng': -99.24258859999999},
#  {'lat': 19.4306069, 'lng': -99.0949899},
#  {'lat': 19.6162033, 'lng': -99.30011809999999},
#  {'lat': 20.6596988, 'lng': -103.3496092},
#  {'lat': 19.0482747, 'lng': -98.42693840000001},
#  {'lat': 29.0729673, 'lng': -110.9559192},
#  {'lat': 17.2237303, 'lng': -100.6281014},
#  {'lat': 20.6124, 'lng': -99.1150509},
#  {'lat': 18.9242095, 'lng': -99.22156590000002},
#  {'lat': 27.9178651, 'lng': -110.9089378},
#  {'lat': 19.5665192, 'lng': -101.7068294},
#  {'lat': 19.3690064, 'lng': -99.7605116},
#  {'lat': 19.6988525, 'lng': -98.75751},
#  {'lat': 19.3557507, 'lng': -99.2993504},
#  {'lat': 19.5345279, 'lng': -99.19073639999999},
#  {'lat': 20.5887932, 'lng': -100.3898881},
#  {'lat': 30.9897648, 'lng': -110.289179},
#  {'lat': 29.9946928, 'lng': -109.7803082},
#  {'lat': 20.1280233, 'lng': -104.3439311},
#  {'lat': 19.2017642, 'lng': -98.8721186},
#  {'lat': 16.7325349, 'lng': -98.6034009},
#  {'lat': 17.4709149, 'lng': -99.3712917},
#  {'lat': 31.3011855, 'lng': -110.9381047},
#  {'lat': 19.8954098, 'lng': -100.4477181},
#  {'lat': 19.4846606, 'lng': -99.1886749},
#  {'lat': 20.5193016, 'lng': -97.9380732},
#  {'lat': 19.4356338, 'lng': -99.1495107},
#  {'lat': 18.4085169, 'lng': -100.4773801},
#  {'lat': 27.0254869, 'lng': -108.941309},
#  {'lat': 19.6528089, 'lng': -99.22313869999999},
#  {'lat': 16.2329693, 'lng': -93.2734517},
#  {'lat': 19.5573493, 'lng': -99.60675309999999},
#  {'lat': 22.4077462, 'lng': -97.92115550000001},
#  {'lat': 16.6030715, 'lng': -98.9714623},
#  {'lat': 19.0376395, 'lng': -98.79602349999999},
#  {'lat': 20.5739314, 'lng': -101.1957172},
#  {'lat': 20.1757001, 'lng': -98.0628862},
#  {'lat': 16.5334303, 'lng': -97.4953304},
#  {'lat': 19.6198998, 'lng': -99.0954726},
#  {'lat': 20.5010443, 'lng': -100.1395169},
#  {'lat': 18.6101834, 'lng': -90.7390245},
#  {'lat': 19.3557507, 'lng': -99.2993504},
#  {'lat': 17.8409173, 'lng': -92.6189273},
#  {'lat': 19.4231994, 'lng': -99.04328869999999},
#  {'lat': 19.7911756, 'lng': -101.1758932},
#  {'lat': 17.0193584, 'lng': -96.74942159999999},
#  {'lat': 20.5279612, 'lng': -100.8112885},
#  {'lat': 18.6144195, 'lng': -99.1781178},
#  {'lat': 25.6866142, 'lng': -100.3161126},
#  {'lat': 17.6724247, 'lng': -97.57204809999999},
#  {'lat': 18.0344322, 'lng': -99.0406186},
#  {'lat': 20.5334645, 'lng': -100.4462861},
#  {'lat': 19.5437751, 'lng': -96.91018059999999},
#  {'lat': 21.8131863, 'lng': -105.204327},
#  {'lat': 18.795868, 'lng': -97.6629495},
#  {'lat': 19.7122732, 'lng': -98.96830729999999},
#  {'lat': 19.1053422, 'lng': -99.58821309999999},
#  {'lat': 17.757147, 'lng': -99.479771},
#  {'lat': 19.106273, 'lng': -96.10632040000002},
#  {'lat': 19.9534201, 'lng': -102.3068608},
#  {'lat': 19.2913424, 'lng': -99.5244687},
#  {'lat': 20.0904802, 'lng': -98.3690922},
#  {'lat': 21.1690704, 'lng': -98.61331880000002},
#  {'lat': 19.1617587, 'lng': -99.6178249},
#  {'lat': 20.9441486, 'lng': -89.56391190000001},
#  {'lat': 17.989456, 'lng': -92.9475061},
#  {'lat': 28.6329957, 'lng': -106.0691004},
#  {'lat': 20.3800556, 'lng': -98.9631789},
#  {'lat': 19.318154, 'lng': -98.2374954},
#  {'lat': 18.3448477, 'lng': -99.5397344},
#  {'lat': 19.9109342, 'lng': -99.07590739999999},
#  {'lat': 19.7129957, 'lng': -99.9515474},
#  {'lat': 19.519222, 'lng': -102.4138738},
#  {'lat': 20.6719563, 'lng': -103.416501},
#  {'lat': 20.6113606, 'lng': -100.3288581},
#  {'lat': 19.6392125, 'lng': -99.1668646},
#  {'lat': 20.6786652, 'lng': -101.3544964},
#  {'lat': 19.3368654, 'lng': -102.3624818},
#  {'lat': 21.3312719, 'lng': -97.754333},
#  {'lat': 20.9233609, 'lng': -98.9500652},
#  {'lat': 16.8681196, 'lng': -95.0442567},
#  {'lat': 20.1462015, 'lng': -101.178725},
#  {'lat': 22.2331041, 'lng': -97.861099},
#  {'lat': 21.2335619, 'lng': -89.1166404},
#  {'lat': 34.1847936, 'lng': -101.7068417},
#  {'lat': 19.3124375, 'lng': -98.2732659},
#  {'lat': 17.9978524, 'lng': -94.6708709},
#  {'lat': 17.741043, 'lng': -99.32708149999999},
#  {'lat': 16.7949714, 'lng': -99.3883874},
#  {'lat': 17.8112504, 'lng': -97.78034819999999},
#  {'lat': 19.9763386, 'lng': -98.86430589999999},
#  {'lat': 15.8969852, 'lng': -96.93780509999999},
#  {'lat': 18.6590633, 'lng': -99.1954432},
#  {'lat': 18.8891562, 'lng': -99.0626377},
#  {'lat': 18.800258, 'lng': -96.571704},
#  {'lat': 19.7075577, 'lng': -99.78839669999999},
#  {'lat': 17.0731842, 'lng': -96.7265889},
#  {'lat': 18.8860004, 'lng': -98.6908754},
#  {'lat': 17.6520624, 'lng': -99.5249616},
#  {'lat': 20.2865414, 'lng': -98.66890339999999},
#  {'lat': 18.0809028, 'lng': -96.1420947},
#  {'lat': 25.8690294, 'lng': -97.50273759999999},
#  {'lat': 17.9309132, 'lng': -97.9579242},
#  {'lat': 19.5699879, 'lng': -99.7650659},
#  {'lat': 19.6860054, 'lng': -99.1260866},
#  {'lat': 18.8954874, 'lng': -99.1732936},
#  {'lat': 19.9521591, 'lng': -100.1619222},
#  {'lat': 20.6295586, 'lng': -87.0738851},
#  {'lat': 16.7516009, 'lng': -93.1029939},
#  {'lat': 19.8277305, 'lng': -99.2037508},
#  {'lat': 21.1139789, 'lng': -86.9423801},
#  {'lat': 20.2588917, 'lng': -97.4011206},
#  {'lat': 19.7122732, 'lng': -98.96830729999999},
#  {'lat': 20.0368036, 'lng': -98.3170569},
#  {'lat': 19.3794059, 'lng': -99.15914459999999},
#  {'lat': 18.4041547, 'lng': -96.8494583},
#  {'lat': 19.7975581, 'lng': -99.8766825},
#  {'lat': 16.4406909, 'lng': -95.0221197},
#  {'lat': 40.2738765, 'lng': -5.0858988},
#  {'lat': 20.0509779, 'lng': -99.2203687},
#  {'lat': 19.8039297, 'lng': -99.0930528},
#  {'lat': 21.8058423, 'lng': -100.9324541},
#  {'lat': 19.6860799, 'lng': -98.87163609999999},
#  {'lat': 19.7059504, 'lng': -101.1949825},
#  {'lat': 18.3297054, 'lng': -98.27585309999999},
#  {'lat': 19.9901766, 'lng': -102.2834075},
#  {'lat': 18.6850824, 'lng': -99.2460619},
#  {'lat': 18.4458276, 'lng': -96.3598367},
#  {'lat': 19.091141, 'lng': -98.881554},
#  {'lat': 18.8937717, 'lng': -98.7205877},
#  {'lat': 19.2630031, 'lng': -99.5324296},
#  {'lat': 19.0765772, 'lng': -98.30211919999999},
#  {'lat': 18.9613407, 'lng': -99.59107379999999},
#  {'lat': 18.5001889, 'lng': -88.296146},
#  {'lat': 20.2040455, 'lng': -98.5754259},
#  {'lat': 20.2769343, 'lng': -98.15016089999999},
#  {'lat': 18.8608694, 'lng': -97.063289},
#  {'lat': 24.8090649, 'lng': -107.3940117},
#  {'lat': 25.7904657, 'lng': -108.985882},
#  {'lat': 19.7287602, 'lng': -99.4617111},
#  {'lat': 20.9891255, 'lng': -89.538319},
#  {'lat': 19.9516359, 'lng': -99.536755},
#  {'lat': 19.6551519, 'lng': -97.9931142},
#  {'lat': 19.9198874, 'lng': -100.0052044},
#  {'lat': 19.5610315, 'lng': -98.9169257},
#  {'lat': 19.5386018, 'lng': -99.1809533},
#  {'lat': 20.0550773, 'lng': -102.7318272},
#  {'lat': 17.5515346, 'lng': -99.5006322},
#  {'lat': 20.653407, 'lng': -105.2253316},
#  {'lat': 30.7286487, 'lng': -115.9894616},
#  {'lat': 19.3994934, 'lng': -98.9896643},
#  {'lat': 19.5345279, 'lng': -99.19073639999999},
#  {'lat': 18.0737638, 'lng': -92.875481},
#  {'lat': 28.6979423, 'lng': -106.1261175},
#  {'lat': 19.6087519, 'lng': -99.3115412},
#  {'lat': 20.7329044, 'lng': -97.8500845},
#  {'lat': 19.4737133, 'lng': -99.2336657},
#  {'lat': 19.6240978, 'lng': -99.30717469999999},
#  {'lat': 20.3786677, 'lng': -99.6508401},
#  {'lat': 19.5966042, 'lng': -98.9402176},
#  {'lat': 19.5345279, 'lng': -99.19073639999999},
#  {'lat': 19.2572314, 'lng': -99.1029664},
#  {'lat': 25.4383234, 'lng': -100.973678},
#  {'lat': 24.0205555, 'lng': -103.4072222},
#  {'lat': 17.5515346, 'lng': -99.5006322},
#  {'lat': 19.2078994, 'lng': -98.93108389999999},
#  {'lat': 15.8336944, 'lng': -97.0424994},
#  {'lat': 18.3680555, 'lng': -100.1761111},
#  {'lat': 19.0414398, 'lng': -98.2062727},
#  {'lat': 19.4755229, 'lng': -99.7149999},
#  {'lat': 19.4045962, 'lng': -98.972843},
#  {'lat': 19.5562275, 'lng': -99.2674713},
#  {'lat': 19.6057728, 'lng': -99.03651119999999},
#  {'lat': 19.4653884, 'lng': -99.59404169999999},
#  {'lat': 23.0122675, 'lng': -109.7352487},
#  {'lat': 19.3605334, 'lng': -99.2267067},
#  {'lat': 22.1325826, 'lng': -100.9136055},
#  {'lat': 18.4665063, 'lng': -97.40038009999999},
#  {'lat': 19.6420614, 'lng': -98.9107373},
#  {'lat': 20.5501224, 'lng': -87.42075179999999},
#  {'lat': 22.1564699, 'lng': -100.9855409},
#  {'lat': 18.4006144, 'lng': -93.2127162},
#  {'lat': 21.3510619, 'lng': -98.2267665},
#  {'lat': 16.9046705, 'lng': -96.5596566},
#  {'lat': 20.0988308, 'lng': -99.15115019999999},
#  {'lat': 24.0277202, 'lng': -104.6531759},
#  {'lat': 19.9521591, 'lng': -100.1619222},
#  {'lat': 18.109679, 'lng': -95.8803616},
#  {'lat': 19.7975581, 'lng': -99.8766825},
#  {'lat': 29.0729673, 'lng': -110.9559192},
#  {'lat': 19.4117213, 'lng': -99.5592077},
#  {'lat': 19.2452342, 'lng': -103.7240868},
#  {'lat': 19.5576533, 'lng': -97.9165939},
#  {'lat': 20.0096889, 'lng': -99.2203687},
#  {'lat': 19.4846606, 'lng': -99.1886749},
#  {'lat': 30.6248514, 'lng': -110.9714055},
#  {'lat': 17.567656, 'lng': -99.39959239999999},
#  {'lat': 19.6326046, 'lng': -99.1090105},
#  {'lat': 20.3475108, 'lng': -103.1942224},
#  {'lat': 19.6726588, 'lng': -99.1648692},
#  {'lat': 20.1453958, 'lng': -98.4410429},
#  {'lat': 17.5330507, 'lng': -97.7214489},
#  {'lat': 19.9114508, 'lng': -99.3506604},
#  {'lat': 19.4042181, 'lng': -99.5302705},
#  {'lat': 19.8379586, 'lng': -97.4564439},
#  {'lat': 20.5326359, 'lng': -99.6323321},
#  {'lat': 19.1804002, 'lng': -99.467615},
#  {'lat': 18.9200983, 'lng': -100.2978762},
#  {'lat': 32.5149469, 'lng': -117.0382471},
#  {'lat': 20.952141, 'lng': -101.4282369},
#  {'lat': 19.8464674, 'lng': -102.1176991},
#  {'lat': 17.9915076, 'lng': -92.9344412},
#  {'lat': 16.3411824, 'lng': -98.053687},
#  {'lat': 18.0842472, 'lng': -88.5710266},
#  {'lat': 19.7899891, 'lng': -99.6684882},
#  {'lat': 18.8390501, 'lng': -99.6760096},
#  {'lat': 19.9198874, 'lng': -100.0052044},
#  {'lat': 18.4753174, 'lng': -100.9769179},
#  {'lat': 19.3994934, 'lng': -98.9896643},
#  {'lat': 22.8905327, 'lng': -109.9167371},
#  {'lat': 20.3367247, 'lng': -98.2240321},
#  {'lat': 18.9892416, 'lng': -99.0594645},
#  {'lat': 21.1367171, 'lng': -98.41221619999999},
#  {'lat': 18.6655167, 'lng': -96.99800839999999},
#  {'lat': 19.6057728, 'lng': -99.03651119999999},
#  {'lat': 17.2772992, 'lng': -94.4506177},
#  {'lat': 19.6126719, 'lng': -99.012202},
#  {'lat': 19.1942041, 'lng': -99.0267076},
#  {'lat': 16.4711295, 'lng': -98.4151885},
#  {'lat': 17.8886548, 'lng': -100.1991306},
#  {'lat': 19.6612661, 'lng': -100.1570626},
#  {'lat': 16.9914845, 'lng': -96.7788461},
#  {'lat': 18.3640239, 'lng': -99.5523977},
#  {'lat': 20.460486, 'lng': -98.0751645},
#  {'lat': 19.1864227, 'lng': -99.4192351},
#  {'lat': 20.0708947, 'lng': -98.6960424},
#  {'lat': 19.3471645, 'lng': -90.7200237},
#  {'lat': 19.7472419, 'lng': -89.8424644},
#  {'lat': 20.6484047, 'lng': -98.6535693},
#  {'lat': 19.2314995, 'lng': -98.8666032},
#  {'lat': 18.2843822, 'lng': -99.46448930000001},
#  {'lat': 20.0615132, 'lng': -97.05452559999999},
#  {'lat': 19.3615578, 'lng': -99.0087486},
#  {'lat': 18.6504879, 'lng': -91.80745859999999},
#  {'lat': 19.8405004, 'lng': -98.9801651},
#  {'lat': 18.3151454, 'lng': -100.2851493},
#  {'lat': 20.4831412, 'lng': -99.21711739999999},
#  {'lat': 17.597969, 'lng': -99.1758462},
#  {'lat': 16.8531086, 'lng': -99.8236533},
#  {'lat': 19.4064492, 'lng': -102.0430476},
#  {'lat': 19.3795136, 'lng': -99.0032236},
#  {'lat': 20.1544793, 'lng': -98.20216099999999},
#  {'lat': 18.9659554, 'lng': -97.8993756},
#  {'lat': 15.7467124, 'lng': -96.5462836},
#  {'lat': 17.3321811, 'lng': -96.4873643},
#  {'lat': 19.3256113, 'lng': -98.4964685},
#  {'lat': 16.211181, 'lng': -97.9792049},
#  {'lat': 19.3467093, 'lng': -99.0798926},
#  {'lat': 19.7485675, 'lng': -88.706081},
#  {'lat': 27.0727573, 'lng': -109.4437493},
#  {'lat': 19.3605334, 'lng': -99.2267067},
#  {'lat': 19.3434287, 'lng': -98.9880319},
#  {'lat': 20.1010608, 'lng': -98.7591311},
#  {'lat': 19.5610315, 'lng': -98.9169257},
#  {'lat': 19.8820941, 'lng': -98.8218954},
#  {'lat': 20.0633589, 'lng': -97.6065055},
#  {'lat': 19.1482351, 'lng': -96.9665476},
#  {'lat': 19.6860799, 'lng': -98.87163609999999},
#  {'lat': 19.4044079, 'lng': -98.0656145},
#  {'lat': 18.8345654, 'lng': -99.5814814},
#  {'lat': 19.4949991, 'lng': -98.5363982},
#  {'lat': 17.9939225, 'lng': -94.5466067},
#  {'lat': 16.9541863, 'lng': -96.7079287},
#  {'lat': 19.5562275, 'lng': -99.2674713},
#  {'lat': 18.1504792, 'lng': -95.1453617},
#  {'lat': 16.8531086, 'lng': -99.8236533},
#  {'lat': 21.9368487, 'lng': -100.0303723},
#  {'lat': 16.5418499, 'lng': -98.0651101},
#  {'lat': 19.4376729, 'lng': -99.9954161},
#  {'lat': 22.0535642, 'lng': -98.1820596},
#  {'lat': 18.134678, 'lng': -99.8324514},
#  {'lat': 19.4968732, 'lng': -99.72326729999999},
#  {'lat': 20.1819021, 'lng': -90.13545859999999},
#  {'lat': 20.2304048, 'lng': -99.21065510000001},
#  {'lat': 18.1310861, 'lng': -96.84314020000001},
#  {'lat': 18.4212621, 'lng': -95.1129658},
#  {'lat': 19.2540675, 'lng': -100.0195984},
#  {'lat': 17.0308889, 'lng': -97.5708659},
#  {'lat': 20.2865414, 'lng': -98.66890339999999}]

# %%
# Convert to DF
df[["lat", "lng"]] = pd.DataFrame(coords)
df.head()
# Out:
#              token             state    municipality  altitude        lat  \
# 0      HKSKLKNMKSK  Estado de Mexico    Huixquilucan      2726  19.360261
# 1        MKSKTMLPN  Estado de Mexico        Timilpan      2741  19.874527
# 2       STTKKNMKSK  Ciudad de Mexico        Coyoacan      2240  19.348693
# 3      MKSKNSHLKTL  Estado de Mexico  Nezahualcoyotl      2220  19.399493
# 4  ALFRSTTMKSKPRKN  Ciudad de Mexico  Alvaro Obregon      2373  19.360533
#
#          lng
# 0 -99.351031
# 1 -99.735809
# 2 -99.162913
# 3 -98.989664
# 4 -99.226707

# %%
# Store
df.to_csv("../../database/clean2/db_origin.csv", index=False)

# %%
# Join with patient_data
patient = pd.read_csv("../../database/clean2/db_patient_origin.csv")
patient_origin_csv = pd.merge(patient, df).sort_values(by="patient_id").drop(columns=["token"])
print(patient_origin_csv.shape)
patient_origin_csv.head()
# Out:
# (1003, 6)
#     patient_id             state    municipality  altitude        lat  \
# 0            0  Estado de Mexico    Huixquilucan      2726  19.360261
# 5            1  Estado de Mexico        Timilpan      2741  19.874527
# 6            2  Ciudad de Mexico        Coyoacan      2240  19.348693
# 37           3  Estado de Mexico  Nezahualcoyotl      2220  19.399493
# 56           4  Ciudad de Mexico  Alvaro Obregon      2373  19.360533
#
#           lng
# 0  -99.351031
# 5  -99.735809
# 6  -99.162913
# 37 -98.989664
# 56 -99.226707

# %%
# Store patient data
patient_origin_csv.to_csv("../../database/clean2/db_patient_origin.csv", index=False)
